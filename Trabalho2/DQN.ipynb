# %%
import gym
import gym_zhed

from stable_baselines.common.policies import MlpPolicy
from stable_baselines import PPO1

env = gym.make('zhedLevel5-v0')
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Environment initialized

# %%
model = PPO1(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=100000)
model.save("deepq_5")

del model # remove to demonstrate saving and loading

model = PPO1.load("deepq_5")
# Out:
# ********** Iteration 0 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00193 |      -0.02772 |       0.28876 |       0.00045 |       2.77207
#      -0.00965 |      -0.02771 |       0.14345 |       0.00168 |       2.77078
#      -0.02076 |      -0.02768 |       0.12223 |       0.00440 |       2.76799
#      -0.02791 |      -0.02763 |       0.04534 |       0.00885 |       2.76343
# Evaluating losses...
#      -0.03260 |      -0.02761 |       0.06646 |       0.01113 |       2.76110
# ----------------------------------
# | EpLenMean       | 8.19         |
# | EpRewMean       | -1           |
# | EpThisIter      | 31           |
# | EpisodesSoFar   | 31           |
# | TimeElapsed     | 0.292        |
# | TimestepsSoFar  | 256          |
# | ev_tdlam_before | -1.86        |
# | loss_ent        | 2.7610998    |
# | loss_kl         | 0.011134509  |
# | loss_pol_entpen | -0.027610999 |
# | loss_pol_surr   | -0.03259774  |
# | loss_vf_loss    | 0.066458374  |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00104 |      -0.02759 |       0.08741 |       0.00018 |       2.75901
#      -0.00825 |      -0.02754 |       0.02929 |       0.00135 |       2.75425
#      -0.01890 |      -0.02749 |       0.03122 |       0.00434 |       2.74854
#      -0.02678 |      -0.02741 |       0.03133 |       0.00929 |       2.74091
# Evaluating losses...
#      -0.02933 |      -0.02736 |       0.01626 |       0.01240 |       2.73643
# ----------------------------------
# | EpLenMean       | 8.05         |
# | EpRewMean       | -1           |
# | EpThisIter      | 32           |
# | EpisodesSoFar   | 63           |
# | TimeElapsed     | 0.405        |
# | TimestepsSoFar  | 512          |
# | ev_tdlam_before | -0.92        |
# | loss_ent        | 2.736432     |
# | loss_kl         | 0.012398907  |
# | loss_pol_entpen | -0.027364321 |
# | loss_pol_surr   | -0.029330365 |
# | loss_vf_loss    | 0.01625966   |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00048 |      -0.02733 |       0.01275 |       0.00020 |       2.73338
#      -0.01189 |      -0.02728 |       0.01183 |       0.00156 |       2.72808
#      -0.03039 |      -0.02722 |       0.00504 |       0.00583 |       2.72187
#      -0.04444 |      -0.02711 |       0.00646 |       0.01487 |       2.71122
# Evaluating losses...
#      -0.04774 |      -0.02704 |       0.00481 |       0.02157 |       2.70397
# ----------------------------------
# | EpLenMean       | 8.64         |
# | EpRewMean       | -1           |
# | EpThisIter      | 25           |
# | EpisodesSoFar   | 88           |
# | TimeElapsed     | 0.519        |
# | TimestepsSoFar  | 768          |
# | ev_tdlam_before | -1.75        |
# | loss_ent        | 2.703971     |
# | loss_kl         | 0.021573607  |
# | loss_pol_entpen | -0.027039709 |
# | loss_pol_surr   | -0.04774381  |
# | loss_vf_loss    | 0.0048126755 |
# ----------------------------------
# ********** Iteration 3 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00208 |      -0.02699 |       0.00362 |       0.00031 |       2.69859
#      -0.01749 |      -0.02673 |       0.00362 |       0.00407 |       2.67307
#      -0.03276 |      -0.02639 |       0.00284 |       0.01472 |       2.63917
#      -0.03703 |      -0.02618 |       0.00253 |       0.02524 |       2.61799
# Evaluating losses...
#      -0.03904 |      -0.02616 |       0.00246 |       0.02783 |       2.61587
# ----------------------------------
# | EpLenMean       | 8.91         |
# | EpRewMean       | -1           |
# | EpThisIter      | 27           |
# | EpisodesSoFar   | 115          |
# | TimeElapsed     | 0.632        |
# | TimestepsSoFar  | 1024         |
# | ev_tdlam_before | -1.33        |
# | loss_ent        | 2.61587      |
# | loss_kl         | 0.027830306  |
# | loss_pol_entpen | -0.0261587   |
# | loss_pol_surr   | -0.039040696 |
# | loss_vf_loss    | 0.0024583305 |
# ----------------------------------
# ********** Iteration 4 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      3.04e-05 |      -0.02612 |       0.00371 |       0.00017 |       2.61207
#      -0.01244 |      -0.02596 |       0.00299 |       0.00185 |       2.59612
#      -0.03268 |      -0.02569 |       0.00298 |       0.00823 |       2.56860
#      -0.03924 |      -0.02538 |       0.00236 |       0.01942 |       2.53822
# Evaluating losses...
#      -0.04256 |      -0.02525 |       0.00248 |       0.02591 |       2.52458
# ----------------------------------
# | EpLenMean       | 9.87         |
# | EpRewMean       | -1           |
# | EpThisIter      | 19           |
# | EpisodesSoFar   | 134          |
# | TimeElapsed     | 0.745        |
# | TimestepsSoFar  | 1280         |
# | ev_tdlam_before | -0.511       |
# | loss_ent        | 2.5245757    |
# | loss_kl         | 0.02591154   |
# | loss_pol_entpen | -0.025245758 |
# | loss_pol_surr   | -0.04255976  |
# | loss_vf_loss    | 0.0024774282 |
# ----------------------------------
# ********** Iteration 5 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00254 |      -0.02514 |       0.00433 |       0.00055 |       2.51429
#      -0.02127 |      -0.02466 |       0.00352 |       0.00645 |       2.46646
#      -0.02949 |      -0.02416 |       0.00367 |       0.01819 |       2.41625
#      -0.03140 |      -0.02405 |       0.00320 |       0.02180 |       2.40503
# Evaluating losses...
#      -0.03803 |      -0.02416 |       0.00324 |       0.01959 |       2.41600
# ----------------------------------
# | EpLenMean       | 11.3         |
# | EpRewMean       | -1           |
# | EpThisIter      | 14           |
# | EpisodesSoFar   | 148          |
# | TimeElapsed     | 0.858        |
# | TimestepsSoFar  | 1536         |
# | ev_tdlam_before | 0.0413       |
# | loss_ent        | 2.4159975    |
# | loss_kl         | 0.019590735  |
# | loss_pol_entpen | -0.024159975 |
# | loss_pol_surr   | -0.038027454 |
# | loss_vf_loss    | 0.0032400317 |
# ----------------------------------
# ********** Iteration 6 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00070 |      -0.02416 |       0.00558 |       0.00062 |       2.41572
#      -0.02186 |      -0.02404 |       0.00471 |       0.00461 |       2.40376
#      -0.02656 |      -0.02380 |       0.00438 |       0.01115 |       2.37961
#      -0.03424 |      -0.02363 |       0.00390 |       0.01479 |       2.36303
# Evaluating losses...
#      -0.03897 |      -0.02353 |       0.00387 |       0.01644 |       2.35290
# ----------------------------------
# | EpLenMean       | 13.1         |
# | EpRewMean       | -1           |
# | EpThisIter      | 11           |
# | EpisodesSoFar   | 159          |
# | TimeElapsed     | 0.973        |
# | TimestepsSoFar  | 1792         |
# | ev_tdlam_before | 0.135        |
# | loss_ent        | 2.3529005    |
# | loss_kl         | 0.016443096  |
# | loss_pol_entpen | -0.023529006 |
# | loss_pol_surr   | -0.038969737 |
# | loss_vf_loss    | 0.003873817  |
# ----------------------------------
# ********** Iteration 7 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00476 |      -0.02338 |       0.00636 |       0.00067 |       2.33846
#      -0.02926 |      -0.02281 |       0.00549 |       0.00784 |       2.28054
#      -0.04118 |      -0.02213 |       0.00476 |       0.02347 |       2.21267
#      -0.04685 |      -0.02190 |       0.00430 |       0.03298 |       2.18983
# Evaluating losses...
#      -0.04520 |      -0.02183 |       0.00416 |       0.03846 |       2.18258
# ----------------------------------
# | EpLenMean       | 14.5         |
# | EpRewMean       | -1           |
# | EpThisIter      | 10           |
# | EpisodesSoFar   | 169          |
# | TimeElapsed     | 1.09         |
# | TimestepsSoFar  | 2048         |
# | ev_tdlam_before | 0.109        |
# | loss_ent        | 2.182581     |
# | loss_kl         | 0.03846284   |
# | loss_pol_entpen | -0.021825809 |
# | loss_pol_surr   | -0.045202814 |
# | loss_vf_loss    | 0.0041580577 |
# ----------------------------------
# ********** Iteration 8 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00109 |      -0.02177 |       0.00803 |       0.00017 |       2.17669
#      -0.00521 |      -0.02165 |       0.00820 |       0.00156 |       2.16485
#      -0.01032 |      -0.02157 |       0.00334 |       0.00421 |       2.15722
#      -0.01102 |      -0.02154 |       0.00495 |       0.00653 |       2.15449
# Evaluating losses...
#      -0.01327 |      -0.02155 |       0.00220 |       0.00653 |       2.15480
# ----------------------------------
# | EpLenMean       | 15.2         |
# | EpRewMean       | -1           |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 170          |
# | TimeElapsed     | 1.2          |
# | TimestepsSoFar  | 2304         |
# | ev_tdlam_before | -0.425       |
# | loss_ent        | 2.1548004    |
# | loss_kl         | 0.006534994  |
# | loss_pol_entpen | -0.021548005 |
# | loss_pol_surr   | -0.013270706 |
# | loss_vf_loss    | 0.0021970612 |
# ----------------------------------
# ********** Iteration 9 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00216 |      -0.02159 |       0.00927 |       0.00026 |       2.15888
#      -0.01423 |      -0.02149 |       0.00989 |       0.00356 |       2.14871
#      -0.01833 |      -0.02128 |       0.00774 |       0.01179 |       2.12767
#      -0.01968 |      -0.02128 |       0.00759 |       0.01289 |       2.12785
# Evaluating losses...
#      -0.02286 |      -0.02134 |       0.00665 |       0.01171 |       2.13417
# ----------------------------------
# | EpLenMean       | 19           |
# | EpRewMean       | -1           |
# | EpThisIter      | 5            |
# | EpisodesSoFar   | 175          |
# | TimeElapsed     | 1.31         |
# | TimestepsSoFar  | 2560         |
# | ev_tdlam_before | -0.0433      |
# | loss_ent        | 2.1341653    |
# | loss_kl         | 0.011712231  |
# | loss_pol_entpen | -0.021341654 |
# | loss_pol_surr   | -0.0228586   |
# | loss_vf_loss    | 0.006651531  |
# ----------------------------------
# ********** Iteration 10 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00154 |      -0.02127 |       0.01053 |       0.00069 |       2.12729
#      -0.01301 |      -0.02117 |       0.01018 |       0.00524 |       2.11669
#      -0.02136 |      -0.02099 |       0.00790 |       0.01323 |       2.09854
#      -0.02386 |      -0.02082 |       0.00763 |       0.01945 |       2.08168
# Evaluating losses...
#      -0.02499 |      -0.02076 |       0.00688 |       0.02105 |       2.07586
# ----------------------------------
# | EpLenMean       | 21.4         |
# | EpRewMean       | -1           |
# | EpThisIter      | 4            |
# | EpisodesSoFar   | 179          |
# | TimeElapsed     | 1.42         |
# | TimestepsSoFar  | 2816         |
# | ev_tdlam_before | -0.169       |
# | loss_ent        | 2.0758643    |
# | loss_kl         | 0.021054972  |
# | loss_pol_entpen | -0.020758642 |
# | loss_pol_surr   | -0.024989571 |
# | loss_vf_loss    | 0.0068781245 |
# ----------------------------------
# ********** Iteration 11 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00178 |      -0.02070 |       0.00907 |       0.00036 |       2.07033
#      -0.02103 |      -0.02048 |       0.00850 |       0.00346 |       2.04809
#      -0.02567 |      -0.02021 |       0.00612 |       0.01288 |       2.02102
#      -0.03203 |      -0.02018 |       0.00602 |       0.01908 |       2.01759
# Evaluating losses...
#      -0.03151 |      -0.02026 |       0.00487 |       0.01898 |       2.02638
# ----------------------------------
# | EpLenMean       | 22.8         |
# | EpRewMean       | -1           |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 181          |
# | TimeElapsed     | 1.53         |
# | TimestepsSoFar  | 3072         |
# | ev_tdlam_before | -0.0366      |
# | loss_ent        | 2.0263767    |
# | loss_kl         | 0.018975018  |
# | loss_pol_entpen | -0.020263769 |
# | loss_pol_surr   | -0.031512454 |
# | loss_vf_loss    | 0.004869082  |
# ----------------------------------
# ********** Iteration 12 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00390 |      -0.02031 |       0.00466 |       0.00025 |       2.03143
#       0.00126 |      -0.02029 |       0.00632 |       0.00071 |       2.02938
#      -0.00360 |      -0.02009 |       0.00275 |       0.00148 |       2.00909
#      -0.01080 |      -0.01976 |       0.00171 |       0.00531 |       1.97568
# Evaluating losses...
#      -0.01469 |      -0.01950 |       0.00227 |       0.01003 |       1.95036
# ----------------------------------
# | EpLenMean       | 22.8         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 181          |
# | TimeElapsed     | 1.65         |
# | TimestepsSoFar  | 3328         |
# | ev_tdlam_before | 0            |
# | loss_ent        | 1.9503553    |
# | loss_kl         | 0.010030531  |
# | loss_pol_entpen | -0.019503552 |
# | loss_pol_surr   | -0.014692905 |
# | loss_vf_loss    | 0.0022737565 |
# ----------------------------------
# ********** Iteration 13 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00072 |      -0.01943 |       0.01819 |       0.00027 |       1.94338
#      -0.00495 |      -0.01925 |       0.01652 |       0.00146 |       1.92484
#      -0.00878 |      -0.01913 |       0.01230 |       0.00359 |       1.91292
#      -0.01187 |      -0.01909 |       0.00899 |       0.00725 |       1.90946
# Evaluating losses...
#      -0.01413 |      -0.01912 |       0.00741 |       0.00919 |       1.91178
# ----------------------------------
# | EpLenMean       | 26.7         |
# | EpRewMean       | -1           |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 183          |
# | TimeElapsed     | 1.76         |
# | TimestepsSoFar  | 3584         |
# | ev_tdlam_before | -0.028       |
# | loss_ent        | 1.9117754    |
# | loss_kl         | 0.009194192  |
# | loss_pol_entpen | -0.019117752 |
# | loss_pol_surr   | -0.01412569  |
# | loss_vf_loss    | 0.0074050273 |
# ----------------------------------
# ********** Iteration 14 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00332 |      -0.01918 |       0.01675 |       0.00089 |       1.91826
#      -0.01048 |      -0.01919 |       0.01490 |       0.00503 |       1.91902
#      -0.01857 |      -0.01913 |       0.01320 |       0.01298 |       1.91293
#      -0.01813 |      -0.01913 |       0.01134 |       0.01972 |       1.91322
# Evaluating losses...
#      -0.01978 |      -0.01919 |       0.01059 |       0.01804 |       1.91856
# ----------------------------------
# | EpLenMean       | 28.9         |
# | EpRewMean       | -1           |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 185          |
# | TimeElapsed     | 1.87         |
# | TimestepsSoFar  | 3840         |
# | ev_tdlam_before | 0.19         |
# | loss_ent        | 1.9185586    |
# | loss_kl         | 0.018036447  |
# | loss_pol_entpen | -0.019185584 |
# | loss_pol_surr   | -0.019778922 |
# | loss_vf_loss    | 0.010594893  |
# ----------------------------------
# ********** Iteration 15 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00113 |      -0.01922 |       0.00171 |       0.00043 |       1.92192
#      -0.00557 |      -0.01928 |       0.00185 |       0.00273 |       1.92798
#      -0.01282 |      -0.01932 |       0.00083 |       0.00822 |       1.93245
#      -0.01591 |      -0.01938 |       0.00049 |       0.01369 |       1.93764
# Evaluating losses...
#      -0.01919 |      -0.01939 |       0.00085 |       0.01620 |       1.93884
# ----------------------------------
# | EpLenMean       | 28.9         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 185          |
# | TimeElapsed     | 1.99         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | 0            |
# | loss_ent        | 1.938839     |
# | loss_kl         | 0.016197314  |
# | loss_pol_entpen | -0.019388389 |
# | loss_pol_surr   | -0.019192724 |
# | loss_vf_loss    | 0.0008467479 |
# ----------------------------------
# ********** Iteration 16 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -7.24e-05 |      -0.01937 |       0.00101 |       0.00045 |       1.93722
#      -0.00585 |      -0.01928 |       0.00120 |       0.00335 |       1.92817
#      -0.01305 |      -0.01920 |       0.00068 |       0.00868 |       1.92032
#      -0.01589 |      -0.01918 |       0.00033 |       0.01529 |       1.91775
# Evaluating losses...
#      -0.01681 |      -0.01921 |       0.00063 |       0.01756 |       1.92050
# ----------------------------------
# | EpLenMean       | 28.9         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 185          |
# | TimeElapsed     | 2.1          |
# | TimestepsSoFar  | 4352         |
# | ev_tdlam_before | 0            |
# | loss_ent        | 1.9205009    |
# | loss_kl         | 0.017564924  |
# | loss_pol_entpen | -0.019205008 |
# | loss_pol_surr   | -0.016806804 |
# | loss_vf_loss    | 0.0006252164 |
# ----------------------------------
# ********** Iteration 17 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00222 |      -0.01925 |       0.00062 |       0.00014 |       1.92499
#      -0.00050 |      -0.01925 |       0.00063 |       0.00063 |       1.92505
#      -0.00662 |      -0.01921 |       0.00034 |       0.00295 |       1.92127
#      -0.01008 |      -0.01912 |       0.00017 |       0.00845 |       1.91190
# Evaluating losses...
#      -0.01127 |      -0.01907 |       0.00034 |       0.01187 |       1.90707
# -----------------------------------
# | EpLenMean       | 28.9          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 185           |
# | TimeElapsed     | 2.21          |
# | TimestepsSoFar  | 4608          |
# | ev_tdlam_before | -1.19e-07     |
# | loss_ent        | 1.9070672     |
# | loss_kl         | 0.011870073   |
# | loss_pol_entpen | -0.019070672  |
# | loss_pol_surr   | -0.011274045  |
# | loss_vf_loss    | 0.00033812856 |
# -----------------------------------
# ********** Iteration 18 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00152 |      -0.01898 |       0.00037 |       0.00029 |       1.89819
#      -0.00498 |      -0.01882 |       0.00038 |       0.00193 |       1.88171
#      -0.00569 |      -0.01866 |       0.00024 |       0.00501 |       1.86604
#      -0.00565 |      -0.01860 |       0.00011 |       0.00925 |       1.85985
# Evaluating losses...
#      -0.00857 |      -0.01862 |       0.00022 |       0.01170 |       1.86207
# ----------------------------------
# | EpLenMean       | 28.9         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 185          |
# | TimeElapsed     | 2.32         |
# | TimestepsSoFar  | 4864         |
# | ev_tdlam_before | 0            |
# | loss_ent        | 1.862068     |
# | loss_kl         | 0.011699996  |
# | loss_pol_entpen | -0.018620681 |
# | loss_pol_surr   | -0.008571513 |
# | loss_vf_loss    | 0.0002176784 |
# ----------------------------------
# ********** Iteration 19 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00103 |      -0.01867 |       0.00022 |       0.00014 |       1.86724
#      -0.00739 |      -0.01884 |       0.00021 |       0.00246 |       1.88350
#      -0.01821 |      -0.01898 |       0.00011 |       0.01001 |       1.89804
#      -0.01739 |      -0.01903 |      5.24e-05 |       0.02198 |       1.90264
# Evaluating losses...
#      -0.01677 |      -0.01903 |       0.00010 |       0.02523 |       1.90265
# -----------------------------------
# | EpLenMean       | 28.9          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 185           |
# | TimeElapsed     | 2.45          |
# | TimestepsSoFar  | 5120          |
# | ev_tdlam_before | -1.19e-07     |
# | loss_ent        | 1.9026471     |
# | loss_kl         | 0.025225716   |
# | loss_pol_entpen | -0.019026471  |
# | loss_pol_surr   | -0.016766943  |
# | loss_vf_loss    | 0.00010341342 |
# -----------------------------------
# ********** Iteration 20 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00040 |      -0.01902 |       0.00012 |       0.00023 |       1.90211
#      -0.00847 |      -0.01887 |       0.00013 |       0.00324 |       1.88659
#      -0.01988 |      -0.01861 |      7.69e-05 |       0.01267 |       1.86109
#      -0.01884 |      -0.01850 |      3.80e-05 |       0.02087 |       1.84954
# Evaluating losses...
#      -0.02289 |      -0.01868 |      6.20e-05 |       0.01846 |       1.86827
# ----------------------------------
# | EpLenMean       | 28.9         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 185          |
# | TimeElapsed     | 2.57         |
# | TimestepsSoFar  | 5376         |
# | ev_tdlam_before | -1.19e-07    |
# | loss_ent        | 1.8682659    |
# | loss_kl         | 0.018459933  |
# | loss_pol_entpen | -0.018682659 |
# | loss_pol_surr   | -0.022885323 |
# | loss_vf_loss    | 6.197786e-05 |
# ----------------------------------
# ********** Iteration 21 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00137 |      -0.01880 |       0.03187 |       0.00058 |       1.87958
#      -0.01205 |      -0.01908 |       0.02873 |       0.00517 |       1.90783
#      -0.01662 |      -0.01927 |       0.02631 |       0.01567 |       1.92650
#      -0.01929 |      -0.01916 |       0.02719 |       0.01694 |       1.91646
# Evaluating losses...
#      -0.02085 |      -0.01909 |       0.02554 |       0.01588 |       1.90941
# ----------------------------------
# | EpLenMean       | 48.1         |
# | EpRewMean       | -1           |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 187          |
# | TimeElapsed     | 2.68         |
# | TimestepsSoFar  | 5632         |
# | ev_tdlam_before | 0.475        |
# | loss_ent        | 1.9094123    |
# | loss_kl         | 0.01587908   |
# | loss_pol_entpen | -0.019094123 |
# | loss_pol_surr   | -0.020853475 |
# | loss_vf_loss    | 0.025537726  |
# ----------------------------------
# ********** Iteration 22 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00216 |      -0.01912 |       0.00424 |       0.00019 |       1.91192
#      -0.01336 |      -0.01924 |       0.00324 |       0.00360 |       1.92364
#      -0.02647 |      -0.01933 |       0.00200 |       0.01468 |       1.93344
#      -0.02385 |      -0.01937 |       0.00107 |       0.02444 |       1.93698
# Evaluating losses...
#      -0.02369 |      -0.01937 |       0.00118 |       0.02480 |       1.93668
# ----------------------------------
# | EpLenMean       | 48.1         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 187          |
# | TimeElapsed     | 2.79         |
# | TimestepsSoFar  | 5888         |
# | ev_tdlam_before | 1.19e-07     |
# | loss_ent        | 1.9366838    |
# | loss_kl         | 0.024797382  |
# | loss_pol_entpen | -0.019366838 |
# | loss_pol_surr   | -0.023694761 |
# | loss_vf_loss    | 0.001181635  |
# ----------------------------------
# ********** Iteration 23 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00021 |      -0.01935 |       0.01211 |      6.53e-05 |       1.93544
#      -0.00599 |      -0.01939 |       0.00999 |       0.00096 |       1.93922
#      -0.01485 |      -0.01949 |       0.00976 |       0.00405 |       1.94913
#      -0.01972 |      -0.01962 |       0.00904 |       0.01089 |       1.96181
# Evaluating losses...
#      -0.02031 |      -0.01967 |       0.00882 |       0.01679 |       1.96669
# ----------------------------------
# | EpLenMean       | 52.1         |
# | EpRewMean       | -1           |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 188          |
# | TimeElapsed     | 2.9          |
# | TimestepsSoFar  | 6144         |
# | ev_tdlam_before | -0.584       |
# | loss_ent        | 1.9666903    |
# | loss_kl         | 0.016786536  |
# | loss_pol_entpen | -0.019666903 |
# | loss_pol_surr   | -0.020313092 |
# | loss_vf_loss    | 0.0088235205 |
# ----------------------------------
# ********** Iteration 24 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00386 |      -0.01966 |       0.00966 |       0.00070 |       1.96594
#      -0.02526 |      -0.01956 |       0.00974 |       0.00854 |       1.95579
#      -0.03300 |      -0.01944 |       0.00914 |       0.02145 |       1.94356
#      -0.03266 |      -0.01951 |       0.00919 |       0.02755 |       1.95065
# Evaluating losses...
#      -0.03449 |      -0.01964 |       0.00928 |       0.02621 |       1.96373
# ----------------------------------
# | EpLenMean       | 55.3         |
# | EpRewMean       | -1           |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 189          |
# | TimeElapsed     | 3.02         |
# | TimestepsSoFar  | 6400         |
# | ev_tdlam_before | 0.446        |
# | loss_ent        | 1.9637265    |
# | loss_kl         | 0.026211902  |
# | loss_pol_entpen | -0.019637264 |
# | loss_pol_surr   | -0.034485962 |
# | loss_vf_loss    | 0.0092791235 |
# ----------------------------------
# ********** Iteration 25 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00036 |      -0.01969 |       0.00083 |       0.00016 |       1.96945
#      -0.01235 |      -0.01974 |       0.00089 |       0.00241 |       1.97410
#      -0.02171 |      -0.01969 |       0.00046 |       0.00993 |       1.96908
#      -0.02186 |      -0.01966 |       0.00024 |       0.01829 |       1.96580
# Evaluating losses...
#      -0.02313 |      -0.01966 |       0.00045 |       0.02081 |       1.96552
# ----------------------------------
# | EpLenMean       | 55.3         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 189          |
# | TimeElapsed     | 3.13         |
# | TimestepsSoFar  | 6656         |
# | ev_tdlam_before | 0            |
# | loss_ent        | 1.9655226    |
# | loss_kl         | 0.020809999  |
# | loss_pol_entpen | -0.019655226 |
# | loss_pol_surr   | -0.023134787 |
# | loss_vf_loss    | 0.0004538634 |
# ----------------------------------
# ********** Iteration 26 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00274 |      -0.01961 |       0.00050 |       0.00037 |       1.96100
#      -0.01815 |      -0.01931 |       0.00051 |       0.00688 |       1.93133
#      -0.02594 |      -0.01886 |       0.00028 |       0.02265 |       1.88587
#      -0.02759 |      -0.01871 |       0.00015 |       0.02951 |       1.87116
# Evaluating losses...
#      -0.02693 |      -0.01876 |       0.00026 |       0.02835 |       1.87597
# ----------------------------------
# | EpLenMean       | 55.3         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 189          |
# | TimeElapsed     | 3.24         |
# | TimestepsSoFar  | 6912         |
# | ev_tdlam_before | 0            |
# | loss_ent        | 1.875972     |
# | loss_kl         | 0.028353333  |
# | loss_pol_entpen | -0.01875972  |
# | loss_pol_surr   | -0.026927115 |
# | loss_vf_loss    | 0.0002555549 |
# ----------------------------------
# ********** Iteration 27 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00157 |      -0.01882 |       0.02181 |       0.00027 |       1.88245
#      -0.00332 |      -0.01885 |       0.02120 |       0.00069 |       1.88548
#      -0.00700 |      -0.01887 |       0.02075 |       0.00170 |       1.88655
#      -0.01144 |      -0.01889 |       0.02081 |       0.00484 |       1.88857
# Evaluating losses...
#      -0.01380 |      -0.01889 |       0.02066 |       0.00732 |       1.88920
# ----------------------------------
# | EpLenMean       | 63           |
# | EpRewMean       | -1           |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 190          |
# | TimeElapsed     | 3.35         |
# | TimestepsSoFar  | 7168         |
# | ev_tdlam_before | 0.211        |
# | loss_ent        | 1.8891966    |
# | loss_kl         | 0.007318711  |
# | loss_pol_entpen | -0.018891966 |
# | loss_pol_surr   | -0.013798524 |
# | loss_vf_loss    | 0.020663211  |
# ----------------------------------
# ********** Iteration 28 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00164 |      -0.01891 |      2.68e-05 |       0.00017 |       1.89079
#      -0.01065 |      -0.01886 |      1.34e-05 |       0.00348 |       1.88644
#      -0.02338 |      -0.01884 |      6.61e-06 |       0.01468 |       1.88365
#      -0.02378 |      -0.01892 |      6.16e-06 |       0.02600 |       1.89201
# Evaluating losses...
#      -0.02567 |      -0.01903 |      6.46e-06 |       0.02473 |       1.90286
# ----------------------------------
# | EpLenMean       | 63           |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 190          |
# | TimeElapsed     | 3.46         |
# | TimestepsSoFar  | 7424         |
# | ev_tdlam_before | -1.19e-07    |
# | loss_ent        | 1.9028552    |
# | loss_kl         | 0.024727166  |
# | loss_pol_entpen | -0.019028552 |
# | loss_pol_surr   | -0.025667906 |
# | loss_vf_loss    | 6.460064e-06 |
# ----------------------------------
# ********** Iteration 29 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      6.17e-05 |      -0.01913 |      7.77e-06 |       0.00033 |       1.91266
#      -0.00398 |      -0.01934 |      7.84e-06 |       0.00214 |       1.93384
#      -0.00789 |      -0.01947 |      6.10e-06 |       0.00680 |       1.94680
#      -0.01207 |      -0.01951 |      3.50e-06 |       0.01259 |       1.95107
# Evaluating losses...
#      -0.01136 |      -0.01952 |      2.37e-06 |       0.01577 |       1.95169
# -----------------------------------
# | EpLenMean       | 63            |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 190           |
# | TimeElapsed     | 3.58          |
# | TimestepsSoFar  | 7680          |
# | ev_tdlam_before | 0             |
# | loss_ent        | 1.9516852     |
# | loss_kl         | 0.015773935   |
# | loss_pol_entpen | -0.019516852  |
# | loss_pol_surr   | -0.011364605  |
# | loss_vf_loss    | 2.3689092e-06 |
# -----------------------------------
# ********** Iteration 30 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00011 |      -0.01948 |       0.03252 |       0.00027 |       1.94773
#      -0.00663 |      -0.01944 |       0.02897 |       0.00276 |       1.94390
#      -0.00761 |      -0.01936 |       0.02453 |       0.00755 |       1.93558
#      -0.01188 |      -0.01935 |       0.02162 |       0.00863 |       1.93527
# Evaluating losses...
#      -0.01254 |      -0.01941 |       0.02022 |       0.00752 |       1.94129
# ----------------------------------
# | EpLenMean       | 69.7         |
# | EpRewMean       | -1           |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 191          |
# | TimeElapsed     | 3.69         |
# | TimestepsSoFar  | 7936         |
# | ev_tdlam_before | -0.691       |
# | loss_ent        | 1.9412911    |
# | loss_kl         | 0.0075168237 |
# | loss_pol_entpen | -0.019412909 |
# | loss_pol_surr   | -0.012543492 |
# | loss_vf_loss    | 0.020215724  |
# ----------------------------------
# ********** Iteration 31 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00157 |      -0.01949 |       0.00070 |       0.00022 |       1.94884
#      -0.00111 |      -0.01967 |       0.00084 |       0.00126 |       1.96718
#      -0.00574 |      -0.01985 |       0.00050 |       0.00313 |       1.98482
#      -0.00824 |      -0.01998 |       0.00024 |       0.00658 |       1.99824
# Evaluating losses...
#      -0.01144 |      -0.02005 |       0.00045 |       0.00993 |       2.00518
# -----------------------------------
# | EpLenMean       | 69.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 191           |
# | TimeElapsed     | 3.8           |
# | TimestepsSoFar  | 8192          |
# | ev_tdlam_before | 0             |
# | loss_ent        | 2.0051787     |
# | loss_kl         | 0.009931137   |
# | loss_pol_entpen | -0.020051787  |
# | loss_pol_surr   | -0.011444405  |
# | loss_vf_loss    | 0.00045481382 |
# -----------------------------------
# ********** Iteration 32 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00097 |      -0.02009 |       0.00044 |       0.00073 |       2.00872
#      -0.00640 |      -0.02018 |       0.00043 |       0.00490 |       2.01765
#      -0.00735 |      -0.02028 |       0.00024 |       0.01222 |       2.02768
#      -0.00682 |      -0.02036 |      9.99e-05 |       0.01565 |       2.03636
# Evaluating losses...
#      -0.00953 |      -0.02039 |       0.00022 |       0.01516 |       2.03872
# -----------------------------------
# | EpLenMean       | 69.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 191           |
# | TimeElapsed     | 3.91          |
# | TimestepsSoFar  | 8448          |
# | ev_tdlam_before | 0             |
# | loss_ent        | 2.0387242     |
# | loss_kl         | 0.015160152   |
# | loss_pol_entpen | -0.020387242  |
# | loss_pol_surr   | -0.009527212  |
# | loss_vf_loss    | 0.00022173434 |
# -----------------------------------
# ********** Iteration 33 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00025 |      -0.02037 |       0.00026 |       0.00012 |       2.03738
#      -0.01011 |      -0.02031 |       0.00026 |       0.00186 |       2.03064
#      -0.02299 |      -0.02019 |       0.00016 |       0.01000 |       2.01876
#      -0.02471 |      -0.02007 |      8.22e-05 |       0.02221 |       2.00667
# Evaluating losses...
#      -0.02457 |      -0.01998 |       0.00014 |       0.02508 |       1.99847
# -----------------------------------
# | EpLenMean       | 69.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 191           |
# | TimeElapsed     | 4.02          |
# | TimestepsSoFar  | 8704          |
# | ev_tdlam_before | 1.19e-07      |
# | loss_ent        | 1.9984702     |
# | loss_kl         | 0.025083156   |
# | loss_pol_entpen | -0.019984702  |
# | loss_pol_surr   | -0.024571974  |
# | loss_vf_loss    | 0.00013656913 |
# -----------------------------------
# ********** Iteration 34 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00190 |      -0.01997 |       0.00016 |       0.00038 |       1.99726
#      -0.01531 |      -0.01989 |       0.00015 |       0.00572 |       1.98949
#      -0.02662 |      -0.01979 |      8.61e-05 |       0.01679 |       1.97935
#      -0.02941 |      -0.01980 |      4.25e-05 |       0.02525 |       1.97960
# Evaluating losses...
#      -0.02762 |      -0.01986 |      7.70e-05 |       0.02802 |       1.98614
# ----------------------------------
# | EpLenMean       | 69.7         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 191          |
# | TimeElapsed     | 4.14         |
# | TimestepsSoFar  | 8960         |
# | ev_tdlam_before | 0            |
# | loss_ent        | 1.9861422    |
# | loss_kl         | 0.028021516  |
# | loss_pol_entpen | -0.01986142  |
# | loss_pol_surr   | -0.027620472 |
# | loss_vf_loss    | 7.69619e-05  |
# ----------------------------------
# ********** Iteration 35 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00239 |      -0.01988 |      9.22e-05 |       0.00021 |       1.98829
#      -0.01381 |      -0.01991 |      9.39e-05 |       0.00517 |       1.99076
#      -0.01856 |      -0.01982 |      5.81e-05 |       0.01754 |       1.98246
#      -0.01885 |      -0.01968 |      3.04e-05 |       0.02784 |       1.96786
# Evaluating losses...
#      -0.02019 |      -0.01963 |      4.75e-05 |       0.03137 |       1.96286
# -----------------------------------
# | EpLenMean       | 69.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 191           |
# | TimeElapsed     | 4.25          |
# | TimestepsSoFar  | 9216          |
# | ev_tdlam_before | 0             |
# | loss_ent        | 1.962862      |
# | loss_kl         | 0.031368647   |
# | loss_pol_entpen | -0.01962862   |
# | loss_pol_surr   | -0.020191541  |
# | loss_vf_loss    | 4.7479814e-05 |
# -----------------------------------
# ********** Iteration 36 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00022 |      -0.01965 |       0.02742 |       0.00016 |       1.96500
#      -0.00683 |      -0.01972 |       0.02693 |       0.00187 |       1.97190
#      -0.01073 |      -0.01983 |       0.02630 |       0.00756 |       1.98342
#      -0.01721 |      -0.01992 |       0.02599 |       0.01521 |       1.99162
# Evaluating losses...
#      -0.01947 |      -0.01991 |       0.02611 |       0.01899 |       1.99075
# ----------------------------------
# | EpLenMean       | 86.7         |
# | EpRewMean       | -1           |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 192          |
# | TimeElapsed     | 4.36         |
# | TimestepsSoFar  | 9472         |
# | ev_tdlam_before | -0.00252     |
# | loss_ent        | 1.9907527    |
# | loss_kl         | 0.018985245  |
# | loss_pol_entpen | -0.019907527 |
# | loss_pol_surr   | -0.019469501 |
# | loss_vf_loss    | 0.026112735  |
# ----------------------------------
# ********** Iteration 37 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00017 |      -0.01988 |       0.00139 |       0.00047 |       1.98799
#      -0.00780 |      -0.01974 |       0.00096 |       0.00398 |       1.97426
#      -0.00988 |      -0.01959 |       0.00061 |       0.01011 |       1.95859
#      -0.01267 |      -0.01958 |       0.00042 |       0.00982 |       1.95843
# Evaluating losses...
#      -0.01365 |      -0.01961 |       0.00048 |       0.00941 |       1.96087
# -----------------------------------
# | EpLenMean       | 86.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 192           |
# | TimeElapsed     | 4.47          |
# | TimestepsSoFar  | 9728          |
# | ev_tdlam_before | 0.225         |
# | loss_ent        | 1.9608744     |
# | loss_kl         | 0.00941309    |
# | loss_pol_entpen | -0.019608743  |
# | loss_pol_surr   | -0.013653109  |
# | loss_vf_loss    | 0.00048379868 |
# -----------------------------------
# ********** Iteration 38 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00042 |      -0.01966 |       0.00084 |       0.00014 |       1.96568
#      -0.00663 |      -0.01977 |       0.00057 |       0.00162 |       1.97686
#      -0.01404 |      -0.01987 |       0.00042 |       0.00761 |       1.98695
#      -0.01617 |      -0.01993 |       0.00028 |       0.01778 |       1.99347
# Evaluating losses...
#      -0.01643 |      -0.01995 |       0.00038 |       0.02042 |       1.99479
# -----------------------------------
# | EpLenMean       | 86.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 192           |
# | TimeElapsed     | 4.58          |
# | TimestepsSoFar  | 9984          |
# | ev_tdlam_before | 0             |
# | loss_ent        | 1.9947909     |
# | loss_kl         | 0.020416392   |
# | loss_pol_entpen | -0.019947909  |
# | loss_pol_surr   | -0.016428834  |
# | loss_vf_loss    | 0.00038115954 |
# -----------------------------------
# ********** Iteration 39 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00071 |      -0.01991 |       0.00073 |       0.00022 |       1.99100
#      -0.00594 |      -0.01973 |       0.00048 |       0.00203 |       1.97345
#      -0.01312 |      -0.01947 |       0.00033 |       0.00776 |       1.94700
#      -0.01683 |      -0.01920 |       0.00023 |       0.01534 |       1.91974
# Evaluating losses...
#      -0.01563 |      -0.01911 |       0.00029 |       0.01743 |       1.91107
# -----------------------------------
# | EpLenMean       | 86.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 192           |
# | TimeElapsed     | 4.7           |
# | TimestepsSoFar  | 10240         |
# | ev_tdlam_before | 0             |
# | loss_ent        | 1.9110708     |
# | loss_kl         | 0.017429315   |
# | loss_pol_entpen | -0.019110708  |
# | loss_pol_surr   | -0.015628647  |
# | loss_vf_loss    | 0.00029445603 |
# -----------------------------------
# ********** Iteration 40 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00158 |      -0.01908 |       0.00057 |       0.00010 |       1.90831
#      -0.00220 |      -0.01891 |       0.00040 |       0.00098 |       1.89071
#      -0.01052 |      -0.01868 |       0.00027 |       0.00449 |       1.86822
#      -0.01285 |      -0.01853 |       0.00020 |       0.01036 |       1.85278
# Evaluating losses...
#      -0.01361 |      -0.01851 |       0.00027 |       0.01251 |       1.85057
# -----------------------------------
# | EpLenMean       | 86.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 192           |
# | TimeElapsed     | 4.81          |
# | TimestepsSoFar  | 10496         |
# | ev_tdlam_before | 0             |
# | loss_ent        | 1.8505743     |
# | loss_kl         | 0.0125127565  |
# | loss_pol_entpen | -0.018505743  |
# | loss_pol_surr   | -0.013611577  |
# | loss_vf_loss    | 0.00026556037 |
# -----------------------------------
# ********** Iteration 41 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00017 |      -0.01849 |       0.00050 |      4.33e-05 |       1.84906
#      -0.00452 |      -0.01840 |       0.00036 |       0.00222 |       1.84007
#      -0.01431 |      -0.01823 |       0.00021 |       0.00971 |       1.82282
#      -0.01379 |      -0.01811 |       0.00016 |       0.01419 |       1.81131
# Evaluating losses...
#      -0.01571 |      -0.01811 |       0.00020 |       0.01417 |       1.81135
# -----------------------------------
# | EpLenMean       | 86.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 192           |
# | TimeElapsed     | 4.92          |
# | TimestepsSoFar  | 10752         |
# | ev_tdlam_before | 0             |
# | loss_ent        | 1.8113477     |
# | loss_kl         | 0.014170825   |
# | loss_pol_entpen | -0.018113477  |
# | loss_pol_surr   | -0.01570988   |
# | loss_vf_loss    | 0.00019884805 |
# -----------------------------------
# ********** Iteration 42 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      6.05e-05 |      -0.01811 |       0.00041 |      4.87e-05 |       1.81100
#      -0.00367 |      -0.01811 |       0.00025 |       0.00077 |       1.81124
#      -0.00705 |      -0.01803 |       0.00019 |       0.00507 |       1.80342
#      -0.01153 |      -0.01800 |       0.00013 |       0.01182 |       1.80021
# Evaluating losses...
#      -0.01238 |      -0.01807 |       0.00016 |       0.01440 |       1.80742
# -----------------------------------
# | EpLenMean       | 86.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 192           |
# | TimeElapsed     | 5.03          |
# | TimestepsSoFar  | 11008         |
# | ev_tdlam_before | 5.96e-08      |
# | loss_ent        | 1.8074247     |
# | loss_kl         | 0.014403052   |
# | loss_pol_entpen | -0.018074246  |
# | loss_pol_surr   | -0.012382052  |
# | loss_vf_loss    | 0.00016006357 |
# -----------------------------------
# ********** Iteration 43 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00067 |      -0.01815 |       0.00033 |       0.00013 |       1.81511
#     -5.87e-05 |      -0.01834 |       0.00021 |       0.00144 |       1.83371
#      -0.00632 |      -0.01853 |       0.00014 |       0.00458 |       1.85255
#      -0.01172 |      -0.01867 |       0.00010 |       0.00912 |       1.86704
# Evaluating losses...
#      -0.01265 |      -0.01876 |       0.00013 |       0.01287 |       1.87570
# -----------------------------------
# | EpLenMean       | 86.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 192           |
# | TimeElapsed     | 5.14          |
# | TimestepsSoFar  | 11264         |
# | ev_tdlam_before | 1.79e-07      |
# | loss_ent        | 1.8756998     |
# | loss_kl         | 0.012868417   |
# | loss_pol_entpen | -0.018756997  |
# | loss_pol_surr   | -0.012651643  |
# | loss_vf_loss    | 0.00013027003 |
# -----------------------------------
# ********** Iteration 44 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00052 |      -0.01878 |       0.00026 |      8.30e-05 |       1.87780
#      -0.00209 |      -0.01879 |       0.00019 |       0.00063 |       1.87864
#      -0.00682 |      -0.01864 |       0.00013 |       0.00367 |       1.86376
#      -0.01189 |      -0.01833 |      9.75e-05 |       0.01177 |       1.83300
# Evaluating losses...
#      -0.01315 |      -0.01820 |       0.00011 |       0.01621 |       1.81979
# ----------------------------------
# | EpLenMean       | 86.7         |
# | EpRewMean       | -1           |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 192          |
# | TimeElapsed     | 5.26         |
# | TimestepsSoFar  | 11520        |
# | ev_tdlam_before | 0            |
# | loss_ent        | 1.8197888    |
# | loss_kl         | 0.01620522   |
# | loss_pol_entpen | -0.018197889 |
# | loss_pol_surr   | -0.013145898 |
# | loss_vf_loss    | 0.0001117707 |
# ----------------------------------
# ********** Iteration 45 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -5.29e-05 |      -0.01813 |       0.00023 |       0.00030 |       1.81302
#      -0.00594 |      -0.01786 |       0.00016 |       0.00347 |       1.78642
#      -0.01294 |      -0.01759 |       0.00010 |       0.01021 |       1.75941
#      -0.01207 |      -0.01737 |      7.72e-05 |       0.01660 |       1.73675
# Evaluating losses...
#      -0.01509 |      -0.01727 |       0.00010 |       0.01824 |       1.72703
# -----------------------------------
# | EpLenMean       | 86.7          |
# | EpRewMean       | -1            |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 192           |
# | TimeElapsed     | 5.37          |
# | TimestepsSoFar  | 11776         |
# | ev_tdlam_before | 5.96e-08      |
# | loss_ent        | 1.7270253     |
# | loss_kl         | 0.018242681   |
# | loss_pol_entpen | -0.017270252  |
# | loss_pol_surr   | -0.015094362  |
# | loss_vf_loss    | 0.00010441573 |
# -----------------------------------
# ********** Iteration 46 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00039 |      -0.01733 |       0.00019 |       0.00013 |       1.73258
#      -0.00368 |      -0.01760 |       0.00012 |       0.00184 |       1.76017
#      -0.01033 |      -0.01792 |      7.83e-05 |       0.00723 |       1.79242
# ...
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X | X | X |   |   |   |
# |   | X |   | X |   |   |
#
# |   |   | X |   |   | G |
# |   |   |   |   |   |   |
# | X
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8c11ef45c085> in <module>
#      11     action, _states = model.predict(obs)
#      12     obs, rewards, dones, info = env.step(action)
# ---> 13     env.render()
#
# c:\users\caroc\desktop\feup\feup-iart\trabalho2\gym-zhed\gym_zhed\envs\zhed_env.py in render(self, mode)
#      80                 x += 1
#      81                 if cell == -1 or (x, y) in self.played_coords:
# ---> 82                     print('X', end=' | ')
#      83                 elif cell == -2:
#      84                     print('G', end=' | ')
#
# C:\ProgramData\Anaconda\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# C:\ProgramData\Anaconda\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# C:\ProgramData\Anaconda\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# C:\ProgramData\Anaconda\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
obs = env.reset()
dones = False
while dones != True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
